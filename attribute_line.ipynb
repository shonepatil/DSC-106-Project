# %%
#Import libraries
import altair as alt
import pandas as pd

# %%
df = pd.read_csv('data_master.csv')
df = df[['year', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence']]
df
# Out:
#         year  acousticness  danceability  energy  instrumentalness  liveness  \
# 0       1920      0.991000         0.598   0.224          0.000522    0.3790
# 1       1920      0.643000         0.852   0.517          0.026400    0.0809
# 2       1920      0.993000         0.647   0.186          0.000018    0.5190
# 3       1920      0.000173         0.730   0.798          0.801000    0.1280
# 4       1920      0.295000         0.704   0.707          0.000246    0.4020
# ...      ...           ...           ...     ...               ...       ...
# 174384  2020      0.009170         0.792   0.866          0.000060    0.1780
# 174385  2021      0.795000         0.429   0.211          0.000000    0.1960
# 174386  2020      0.806000         0.671   0.589          0.920000    0.1130
# 174387  2021      0.920000         0.462   0.240          0.000000    0.1130
# 174388  2020      0.239000         0.677   0.460          0.891000    0.2150
#
#         speechiness  valence
# ...

# %%
data = df.groupby('year').mean().reset_index()
data = data.melt('year').rename(columns={'year': 'Year', 'value': 'Value', 'variable': 'Attribute'})
data
# Out:
#      Year     Attribute     Value
# 0    1920  acousticness  0.631242
# 1    1921  acousticness  0.862105
# 2    1922  acousticness  0.828934
# 3    1923  acousticness  0.957247
# 4    1924  acousticness  0.940200
# ..    ...           ...       ...
# 709  2017       valence  0.436313
# 710  2018       valence  0.426566
# 711  2019       valence  0.457813
# 712  2020       valence  0.468030
# 713  2021       valence  0.451908
#
# [714 rows x 3 columns]

# %%
selection = alt.selection_multi(fields=['Attribute'], bind='legend')

alt.Chart(data).mark_line(
).encode(
    x='Year',
    y='Value',
    color='Attribute',
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
).add_selection(
    selection
).properties(
    width=600, height=300
)
# Out:
# alt.Chart(...)
