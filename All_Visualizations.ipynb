# %%
# Genre Line
# Shows collaboration rate for each genre from 1970 to 2020

# %run genre_line.ipynb

line_chart | legend # For usage, shift click different countries
# Out:
# <ipython-input-3-5c51d63fb89f>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   collabs = collabs[collabs['primary_genre'].isin(top_g)][(collabs['year'] >= 1970) & (collabs['year'] <= 2020)]
# alt.HConcatChart(...)

# %%
# Genre and Popularity scatterplot
# Select subsection of scatterplot to see corresponding bar plots

# %run genre_popularity_scatter.ipynb

scatter | bar_pop & bar_collab
# Out:
# alt.HConcatChart(...)

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# Network graphs for top 50 Rap songs
# Artists are nodes; Songs are Edges
# Highlight edges to see song name and popularity level out of 100

# %run collab_popularity_network_rap.ipynb

g.show('rap.html')
# Out:
#         <iframe
#             width="800"
#             height="950"
#             src="rap.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Network graphs for top 50 Pop songs
# Artists are nodes; Songs are Edges
# Highlight edges to see song name and popularity level out of 100

# %run collab_popularity_network_pop.ipynb

g.show('pop.html')
# Out:
#         <iframe
#             width="800"
#             height="950"
#             src="pop.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Attribute Line Graph
# Attributes over time
# Shift click on legend to focus on specific attributes

# %run attribute_line.ipynb

attr_line
# Out:
# alt.Chart(...)

# %%
# Collab Line Graph
# Average collaboration rate over time

# %run collab_line.ipynb

collab
# Out:
# alt.LayerChart(...)

# %%
# Time Scaled Top Collaborators Graph
# Compare Top collaborators between two years
# Slider controls year for top graph
# Dropdown controls year for bottom graph

# %run timescaled_top_collaborators.ipynb

year_slider & year_dropdown
# Out:
# alt.VConcatChart(...)
