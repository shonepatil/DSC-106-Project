# %%
import pandas as pd
import numpy as np
import altair as alt
import networkx as nx
from pyvis.network import Network
from ast import literal_eval

# %%
# bring in data
df = pd.read_csv('data_master.csv')

# Create year column
df['year'] = df['release_date'].astype('datetime64[ns]').apply(lambda x: x.year)

# Filter needed columns
df = df[df['is_collab'] == True][['popularity', 'name', 'primary_genre', 'year', 'artists', 'collaborators']]
df['artists'] = df['artists'].apply(lambda x: literal_eval(x))

# %%
# Find all nodes and edges to plot
top50_pop = df[df['primary_genre'] == 'pop'].sort_values(by='popularity', ascending = False)\
    .head(50)[['artists', 'name', 'popularity','primary_genre']]
top50_pop

# Create graph
graph = nx.Graph()

# Populate Edges
edges = []
for row in top50_pop.iterrows():
    items = row[1]['artists']
    edges += [(items[i],items[j],{'title': row[1]['name'] + ", Popularity: " + str(row[1]['popularity']), \
                                  'width': row[1]['popularity']/100 + 2}) \
              for i in range(len(items)) for j in range(i+1, len(items))]
    
graph.add_edges_from(edges)

# Compute positions for viz.
pos = nx.spring_layout(graph)

# Display graph of top 50 pop collaborations
g = Network(height = 950, width = 800, notebook = True, bgcolor="#222222", font_color="white")
g.toggle_hide_edges_on_drag(False)
g.force_atlas_2based()
g.from_nx(graph)
g.show('ex.html')
# Out:
#         <iframe
#             width="800"
#             height="950"
#             src="ex.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Find all nodes and edges to plot
top50_rap = df[df['primary_genre'] == 'rap'].sort_values(by='popularity', ascending = False)\
    .head(50)[['artists', 'name', 'popularity','primary_genre']]
top50_rap

# Create graph
graph = nx.Graph()

# Populate Edges
edges = []
for row in top50_rap.iterrows():
    items = row[1]['artists']
    edges += [(items[i],items[j],{'title': row[1]['name'] + ", Popularity: " + str(row[1]['popularity']), \
                                  'width': row[1]['popularity']/100 + 2}) \
              for i in range(len(items)) for j in range(i+1, len(items))]
    
graph.add_edges_from(edges)

# Compute positions for viz.
pos = nx.spring_layout(graph)

# Display graph of top 50 rap collaborations
g = Network(height = 950, width = 800, notebook = True, bgcolor="#222222", font_color="white")
g.toggle_hide_edges_on_drag(False)
g.force_atlas_2based()
g.from_nx(graph)
g.show('exa.html')
# Out:
#         <iframe
#             width="800"
#             height="950"
#             src="exa.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
df[df['primary_genre'] == 'rap'].sort_values(by='popularity', ascending = False).head(50)[['artists', 'name', 'popularity',\
                                                             'primary_genre']]
# Out:
#                                                  artists  \
# 19892                              [DaBaby, Roddy Ricch]
# 19902          [Internet Money, Gunna, Don Toliver, NAV]
# 19882                                  [Drake, Lil Durk]
# 19936          [Internet Money, Gunna, Don Toliver, NAV]
# 20000                               [Eminem, Juice WRLD]
# 20030                                    [Future, Drake]
# 19920       [Jack Harlow, Tory Lanez, DaBaby, Lil Wayne]
# 19492                           [Post Malone, 21 Savage]
# 19918                          [21 Savage, Metro Boomin]
# 20052               [THE SCOTTS, Travis Scott, Kid Cudi]
# 19486                            [Post Malone, Swae Lee]
# 19750               [JACKBOYS, Travis Scott, Young Thug]
# 20002                      [Kid Cudi, Skepta, Pop Smoke]
# 16263                                [Eminem, Nate Dogg]
# 19690                             [Mustard, Roddy Ricch]
# 39228                                    [Drake, Giveon]
# 19964                             [Future, Lil Uzi Vert]
# 20040                            [Big Sean, Post Malone]
# 19792                            [Post Malone, Swae Lee]
# 76568                                 [Octavian, Skepta]
# 19478                                  [Lil Baby, Gunna]
# 19948                   [21 Savage, Metro Boomin, Drake]
# 20036                            [Jack Harlow, Big Sean]
# 18928                        [Wiz Khalifa, Charlie Puth]
# 20006                                [Lil Baby, 42 Dugg]
# 19504                                 [Meek Mill, Drake]
# 17880                                  [Eminem, Rihanna]
# 19278                             [Offset, Metro Boomin]
# 19496                              [Metro Boomin, Gunna]
# 19812                          [Post Malone, Young Thug]
# 19742                                 [Drake, Rick Ross]
# 19706                             [Roddy Ricch, Mustard]
# 19072                               [Post Malone, Quavo]
# 20038                                [Gunna, Young Thug]
# 14863                                     [Coolio, L.V.]
# 39362                 [Travis Scott, Young Thug, M.I.A.]
# 19276                   [Tyler, The Creator, Kali Uchis]
# 19156                              [Drake, WizKid, Kyla]
# 19408                         [French Montana, Swae Lee]
# 20044                               [Lil Durk, King Von]
# 19558                              [Kendrick Lamar, SZA]
# 17684                               [JAY-Z, Alicia Keys]
# 20042  [G Herbo, Juice WRLD, Lil Uzi Vert, Chance the...
# 38884                               [A$AP Rocky, Skepta]
# 19576                       [Post Malone, Ty Dolla $ign]
# 39044                [JACKBOYS, Pop Smoke, Travis Scott]
# 39300                            [Jack Harlow, Big Sean]
# 19536                  [A Boogie Wit da Hoodie, 6ix9ine]
# 16894                                  [50 Cent, Olivia]
# 15665                              [Dr. Dre, Snoop Dogg]
#
#                                                     name  popularity  \
# 19892                       ROCKSTAR (feat. Roddy Ricch)          91
# 19902                                           Lemonade          90
# 19882               Laugh Now Cry Later (feat. Lil Durk)          89
# 19936          Lemonade (feat. Gunna, Don Toliver & NAV)          88
# 20000                        Godzilla (feat. Juice WRLD)          86
# 20030                         Life Is Good (feat. Drake)          85
# 19920  WHATS POPPIN (feat. DaBaby, Tory Lanez & Lil W...          85
# 19492                         rockstar (feat. 21 Savage)          85
# 19918                                             Runnin          84
# 20052                                         THE SCOTTS          84
# 19486      Sunflower - Spider-Man: Into the Spider-Verse          84
# 19750                        OUT WEST (feat. Young Thug)          83
# 20002                 Show Out (with Skepta & Pop Smoke)          83
# 16263                                   'Till I Collapse          83
# 19690                         Ballin' (with Roddy Ricch)          83
# 39228                   Chicago Freestyle (feat. Giveon)          83
# 19964                                   Drankin N Smokin          83
# 20040                         Wolves (feat. Post Malone)          82
# 19792      Sunflower - Spider-Man: Into the Spider-Verse          82
# 76568                                         Papi Chulo          82
# 19478                   Drip Too Hard (Lil Baby & Gunna)          82
# 19948                        Mr. Right Now (feat. Drake)          82
# 20036                           Way Out (feat. Big Sean)          81
# 18928                 See You Again (feat. Charlie Puth)          81
# 20006                            We Paid (feat. 42 Dugg)          81
# 19504                            Going Bad (feat. Drake)          81
# 17880                               Love The Way You Lie          81
# 19278                    Ric Flair Drip (& Metro Boomin)          81
# 19496                          Space Cadet (feat. Gunna)          81
# 19812                        Goodbyes (feat. Young Thug)          81
# 19742           Money In The Grave (Drake ft. Rick Ross)          81
# 19706                       High Fashion (feat. Mustard)          81
# 19072                                    Congratulations          81
# 20038               DOLLAZ ON MY HEAD (feat. Young Thug)          81
# 14863                                 Gangsta's Paradise          81
# 39362              FRANCHISE (feat. Young Thug & M.I.A.)          81
# 19276                   See You Again (feat. Kali Uchis)          80
# 19156                                          One Dance          80
# 19408                                      Unforgettable          80
# 20044                     Still Trappin' (with King Von)          80
# 19558                           All The Stars (with SZA)          80
# 17684                               Empire State Of Mind          80
# 20042                                               PTSD          80
# 38884          Praise The Lord (Da Shine) (feat. Skepta)          80
# 19576                       Psycho (feat. Ty Dolla $ign)          80
# 39044                                              GATTI          80
# 39300                           Way Out (feat. Big Sean)          80
# 19536                            Swervin (feat. 6ix9ine)          80
# 16894                                         Candy Shop          79
# 15665                                       Still D.R.E.          79
#
#       primary_genre
# 19892           rap
# 19902           rap
# 19882           rap
# 19936           rap
# 20000           rap
# 20030           rap
# 19920           rap
# 19492           rap
# 19918           rap
# 20052           rap
# 19486           rap
# 19750           rap
# 20002           rap
# 16263           rap
# 19690           rap
# 39228           rap
# 19964           rap
# 20040           rap
# 19792           rap
# 76568           rap
# 19478           rap
# 19948           rap
# 20036           rap
# 18928           rap
# 20006           rap
# 19504           rap
# 17880           rap
# 19278           rap
# 19496           rap
# 19812           rap
# 19742           rap
# 19706           rap
# 19072           rap
# 20038           rap
# 14863           rap
# 39362           rap
# 19276           rap
# 19156           rap
# 19408           rap
# 20044           rap
# 19558           rap
# 17684           rap
# 20042           rap
# 38884           rap
# 19576           rap
# 39044           rap
# 39300           rap
# 19536           rap
# 16894           rap
# 15665           rap
